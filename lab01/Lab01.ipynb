# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

# %% [markdown]
# ## Q1

# %%
def gener1(a, b, m, seed):
    arr = []
    x = seed
    arr.append(x)
    while True:
        x = (a * x + b) % m
        if(x == seed):
            break
        arr.append(x)
    return arr

# %%
print("sequence for a=6, b=0, m=11, and,")
for i in range(0, 11):
    print("seed =", i, end=": ")
    print(gener1(6, 0, 11, i))
# Out:
# sequence for a=6, b=0, m=11, and,
# seed = 0: [0]
# seed = 1: [1, 6, 3, 7, 9, 10, 5, 8, 4, 2]
# seed = 2: [2, 1, 6, 3, 7, 9, 10, 5, 8, 4]
# seed = 3: [3, 7, 9, 10, 5, 8, 4, 2, 1, 6]
# seed = 4: [4, 2, 1, 6, 3, 7, 9, 10, 5, 8]
# seed = 5: [5, 8, 4, 2, 1, 6, 3, 7, 9, 10]
# seed = 6: [6, 3, 7, 9, 10, 5, 8, 4, 2, 1]
# seed = 7: [7, 9, 10, 5, 8, 4, 2, 1, 6, 3]
# seed = 8: [8, 4, 2, 1, 6, 3, 7, 9, 10, 5]
# seed = 9: [9, 10, 5, 8, 4, 2, 1, 6, 3, 7]
# seed = 10: [10, 5, 8, 4, 2, 1, 6, 3, 7, 9]

# %%
print("sequence for a=3, b=0, m=11, and,")
for i in range(0,11):
    print("seed =", i, end=": ")
    print(gener1(3, 0, 11, i))
# Out:
# sequence for a=3, b=0, m=11, and,
# seed = 0: [0]
# seed = 1: [1, 3, 9, 5, 4]
# seed = 2: [2, 6, 7, 10, 8]
# seed = 3: [3, 9, 5, 4, 1]
# seed = 4: [4, 1, 3, 9, 5]
# seed = 5: [5, 4, 1, 3, 9]
# seed = 6: [6, 7, 10, 8, 2]
# seed = 7: [7, 10, 8, 2, 6]
# seed = 8: [8, 2, 6, 7, 10]
# seed = 9: [9, 5, 4, 1, 3]
# seed = 10: [10, 8, 2, 6, 7]

# %% [markdown]
# ---

# %% [markdown]
# ## Q2

# %%
def gener2(a, b, m, seed):
    x = seed
    u = x/m
    ui = []
    xi = []
    # ui.append(u)
    # xi.append(x)
    mapp = dict()
    checker = dict()
    for i in range(0, 20):
        mapp[i] = 0
    for _ in range(10000):
        x = (a*x + b) % m
        u = x/m
        if x in checker:
            break
        else:
            checker[x]=1
        xi.append(x)
        ui.append(u)

        key = round(u*20) % 20
        mapp[key] += 1
        
    return  mapp

ranges = ['0, 0.05',
          '0.05, 0.1',
          '0.1, 0.15',
          '0.15, 0.2',
          '0.2, 0.25',
          '0.25, 0.3',
          '0.3, 0.35',
          '0.35, 0.4',
          '0.4, 0.45',
          '0.45, 0.5',
          '0.5, 0.55',
          '0.55, 0.6',
          '0.6, 0.65',
          '0.65, 0.7',
          '0.7, 0.75',
          '0.75, 0.8',
          '0.8, 0.85',
          '0.85, 0.9',
          '0.9, 0.95',
          '0.95, 1']

# %% [markdown]
# #### a = 1597, b = 1, m = 244944, seed = 1

# %%
mapp1 = gener2(1597, 1, 244944, 1)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])
# Out:
# 0, 0.05 : 496
# 0.05, 0.1 : 455
# 0.1, 0.15 : 544
# 0.15, 0.2 : 516
# 0.2, 0.25 : 476
# 0.25, 0.3 : 496
# 0.3, 0.35 : 451
# 0.35, 0.4 : 554
# 0.4, 0.45 : 518
# 0.45, 0.5 : 477
# 0.5, 0.55 : 494
# 0.55, 0.6 : 462
# 0.6, 0.65 : 554
# 0.65, 0.7 : 505
# 0.7, 0.75 : 488
# 0.75, 0.8 : 485
# 0.8, 0.85 : 468
# 0.85, 0.9 : 554
# 0.9, 0.95 : 511
# 0.95, 1 : 496

# %%
keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 1')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 1')
plt.show()

# %% [markdown]
# #### a=51749, b=1, m=244944, seed=1

# %%
mapp2 = gener2(51749, 1, 244944, 1)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])
# Out:
# 0, 0.05 : 195
# 0.05, 0.1 : 194
# 0.1, 0.15 : 195
# 0.15, 0.2 : 193
# 0.2, 0.25 : 195
# 0.25, 0.3 : 195
# 0.3, 0.35 : 194
# 0.35, 0.4 : 194
# 0.4, 0.45 : 194
# 0.45, 0.5 : 195
# 0.5, 0.55 : 195
# 0.55, 0.6 : 194
# 0.6, 0.65 : 195
# 0.65, 0.7 : 193
# 0.7, 0.75 : 195
# 0.75, 0.8 : 195
# 0.8, 0.85 : 194
# 0.85, 0.9 : 194
# 0.9, 0.95 : 194
# 0.95, 1 : 195

# %%
keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 1')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 1')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### a = 1597, b = 1, m = 244944, seed = 3

# %%
mapp1 = gener2(1597, 1, 244944, 3)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])

keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 3')
plt.show()
# Out:
# 0, 0.05 : 498
# 0.05, 0.1 : 491
# 0.1, 0.15 : 572
# 0.15, 0.2 : 503
# 0.2, 0.25 : 459
# 0.25, 0.3 : 497
# 0.3, 0.35 : 485
# 0.35, 0.4 : 567
# 0.4, 0.45 : 499
# 0.45, 0.5 : 460
# 0.5, 0.55 : 501
# 0.55, 0.6 : 465
# 0.6, 0.65 : 548
# 0.65, 0.7 : 493
# 0.7, 0.75 : 462
# 0.75, 0.8 : 485
# 0.8, 0.85 : 477
# 0.85, 0.9 : 565
# 0.9, 0.95 : 517
# 0.95, 1 : 456

# %% [markdown]
# #### a = 51749, b = 1, m = 244944, seed = 3

# %%
mapp2 = gener2(51749, 1, 244944, 3)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])

keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 3')
plt.show()
# Out:
# 0, 0.05 : 494
# 0.05, 0.1 : 503
# 0.1, 0.15 : 502
# 0.15, 0.2 : 501
# 0.2, 0.25 : 510
# 0.25, 0.3 : 503
# 0.3, 0.35 : 495
# 0.35, 0.4 : 513
# 0.4, 0.45 : 511
# 0.45, 0.5 : 517
# 0.5, 0.55 : 515
# 0.55, 0.6 : 502
# 0.6, 0.65 : 499
# 0.65, 0.7 : 490
# 0.7, 0.75 : 495
# 0.75, 0.8 : 496
# 0.8, 0.85 : 488
# 0.85, 0.9 : 495
# 0.9, 0.95 : 484
# 0.95, 1 : 487

# %% [markdown]
# ---

# %% [markdown]
# #### a=1597, b=1, m=244944, seed=4

# %%
mapp1 = gener2(1597, 1, 244944, 4)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])

keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 4')
plt.show()
# Out:
# 0, 0.05 : 460
# 0.05, 0.1 : 501
# 0.1, 0.15 : 468
# 0.15, 0.2 : 586
# 0.2, 0.25 : 502
# 0.25, 0.3 : 465
# 0.3, 0.35 : 490
# 0.35, 0.4 : 488
# 0.4, 0.45 : 558
# 0.45, 0.5 : 505
# 0.5, 0.55 : 448
# 0.55, 0.6 : 503
# 0.6, 0.65 : 478
# 0.65, 0.7 : 557
# 0.7, 0.75 : 501
# 0.75, 0.8 : 448
# 0.8, 0.85 : 506
# 0.85, 0.9 : 468
# 0.9, 0.95 : 575
# 0.95, 1 : 493

# %% [markdown]
# #### a=51749, b=1, m=244944, seed=4

# %%
mapp2 = gener2(51749, 1, 244944, 4)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])

keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 4')
plt.show()
# Out:
# 0, 0.05 : 510
# 0.05, 0.1 : 501
# 0.1, 0.15 : 495
# 0.15, 0.2 : 500
# 0.2, 0.25 : 503
# 0.25, 0.3 : 504
# 0.3, 0.35 : 500
# 0.35, 0.4 : 498
# 0.4, 0.45 : 501
# 0.45, 0.5 : 503
# 0.5, 0.55 : 494
# 0.55, 0.6 : 499
# 0.6, 0.65 : 501
# 0.65, 0.7 : 507
# 0.7, 0.75 : 498
# 0.75, 0.8 : 502
# 0.8, 0.85 : 488
# 0.85, 0.9 : 500
# 0.9, 0.95 : 502
# 0.95, 1 : 494

# %% [markdown]
# ---

# %% [markdown]
# #### a=1597, b=1, m=244944, seed=6

# %%
mapp1 = gener2(1597, 1, 244944, 6)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])

keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 6')
plt.show()
# Out:
# 0, 0.05 : 474
# 0.05, 0.1 : 524
# 0.1, 0.15 : 534
# 0.15, 0.2 : 508
# 0.2, 0.25 : 463
# 0.25, 0.3 : 494
# 0.3, 0.35 : 526
# 0.35, 0.4 : 535
# 0.4, 0.45 : 497
# 0.45, 0.5 : 481
# 0.5, 0.55 : 467
# 0.55, 0.6 : 524
# 0.6, 0.65 : 535
# 0.65, 0.7 : 491
# 0.7, 0.75 : 486
# 0.75, 0.8 : 467
# 0.8, 0.85 : 496
# 0.85, 0.9 : 526
# 0.9, 0.95 : 505
# 0.95, 1 : 467

# %% [markdown]
# #### a=51749, b=1, m=244944, seed=6

# %%
mapp2 = gener2(51749, 1, 244944, 6)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])

keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 6')
plt.show()
# Out:
# 0, 0.05 : 510
# 0.05, 0.1 : 498
# 0.1, 0.15 : 499
# 0.15, 0.2 : 505
# 0.2, 0.25 : 487
# 0.25, 0.3 : 515
# 0.3, 0.35 : 495
# 0.35, 0.4 : 492
# 0.4, 0.45 : 500
# 0.45, 0.5 : 504
# 0.5, 0.55 : 492
# 0.55, 0.6 : 505
# 0.6, 0.65 : 498
# 0.65, 0.7 : 488
# 0.7, 0.75 : 515
# 0.75, 0.8 : 490
# 0.8, 0.85 : 505
# 0.85, 0.9 : 502
# 0.9, 0.95 : 501
# 0.95, 1 : 499

# %% [markdown]
# ---

# %% [markdown]
# #### a=1597, b=1, m=244944, seed=7

# %%
mapp1 = gener2(1597, 1, 244944, 7)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])

keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 7')
plt.show()
# Out:
# 0, 0.05 : 555
# 0.05, 0.1 : 509
# 0.1, 0.15 : 486
# 0.15, 0.2 : 495
# 0.2, 0.25 : 455
# 0.25, 0.3 : 549
# 0.3, 0.35 : 507
# 0.35, 0.4 : 476
# 0.4, 0.45 : 500
# 0.45, 0.5 : 445
# 0.5, 0.55 : 562
# 0.55, 0.6 : 526
# 0.6, 0.65 : 468
# 0.65, 0.7 : 512
# 0.7, 0.75 : 452
# 0.75, 0.8 : 562
# 0.8, 0.85 : 503
# 0.85, 0.9 : 470
# 0.9, 0.95 : 497
# 0.95, 1 : 471

# %% [markdown]
# #### a=51749, b=1, m=244944, seed=7

# %%
mapp2 = gener2(51749, 1, 244944, 7)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])

keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 7')
plt.show()
# Out:
# 0, 0.05 : 496
# 0.05, 0.1 : 515
# 0.1, 0.15 : 503
# 0.15, 0.2 : 499
# 0.2, 0.25 : 493
# 0.25, 0.3 : 494
# 0.3, 0.35 : 507
# 0.35, 0.4 : 491
# 0.4, 0.45 : 505
# 0.45, 0.5 : 504
# 0.5, 0.55 : 492
# 0.55, 0.6 : 507
# 0.6, 0.65 : 500
# 0.65, 0.7 : 509
# 0.7, 0.75 : 492
# 0.75, 0.8 : 495
# 0.8, 0.85 : 507
# 0.85, 0.9 : 488
# 0.9, 0.95 : 507
# 0.95, 1 : 496

# %% [markdown]
# ---

# %% [markdown]
# #### a=1597, b=1, m=244944, seed=9

# %%
mapp1 = gener2(1597, 1, 244944, 9)
mapp1 = OrderedDict(sorted(mapp1.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp1[i])

keys = list(mapp1.keys())

newMapp1 = dict()
for (key, value) in mapp1.items():
    newMapp1[round(key*0.05, 2)] = value

x = list(newMapp1.keys())
y = list(newMapp1.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='green', width = 0.3, label='a = 1597, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 1597, b = 1, m = 244944, seed = 9')
plt.show()
# Out:
# 0, 0.05 : 460
# 0.05, 0.1 : 570
# 0.1, 0.15 : 510
# 0.15, 0.2 : 466
# 0.2, 0.25 : 501
# 0.25, 0.3 : 481
# 0.3, 0.35 : 565
# 0.35, 0.4 : 500
# 0.4, 0.45 : 477
# 0.45, 0.5 : 499
# 0.5, 0.55 : 455
# 0.55, 0.6 : 568
# 0.6, 0.65 : 512
# 0.65, 0.7 : 466
# 0.7, 0.75 : 509
# 0.75, 0.8 : 445
# 0.8, 0.85 : 543
# 0.85, 0.9 : 510
# 0.9, 0.95 : 456
# 0.95, 1 : 507

# %% [markdown]
# #### a=51749, b=1, m=244944, seed=9

# %%
mapp2 = gener2(51749, 1, 244944, 9)
mapp2 = OrderedDict(sorted(mapp2.items()))

for i in range(0, 20):
    print(ranges[i], ":", mapp2[i])

keys = list(mapp2.keys())

newMapp2 = dict()
for (key, value) in mapp2.items():
    newMapp2[round(key*0.05, 2)] = value

x = list(newMapp2.keys())
y = list(newMapp2.values())

plt.figure(figsize=(18, 5))
width = np.min(np.diff(keys))/3

plt.bar(keys - 0.5*width, y, color='blue', width = 0.3, label='a = 51749, seed = 2')
plt.xticks(keys, ranges, rotation='vertical')
plt.title('a = 51749, b = 1, m = 244944, seed = 9')
plt.show()
# Out:
# 0, 0.05 : 504
# 0.05, 0.1 : 486
# 0.1, 0.15 : 503
# 0.15, 0.2 : 513
# 0.2, 0.25 : 500
# 0.25, 0.3 : 491
# 0.3, 0.35 : 501
# 0.35, 0.4 : 503
# 0.4, 0.45 : 499
# 0.45, 0.5 : 491
# 0.5, 0.55 : 505
# 0.55, 0.6 : 514
# 0.6, 0.65 : 490
# 0.65, 0.7 : 488
# 0.7, 0.75 : 502
# 0.75, 0.8 : 514
# 0.8, 0.85 : 499
# 0.85, 0.9 : 482
# 0.9, 0.95 : 505
# 0.95, 1 : 510

# %% [markdown]
# ---

# %% [markdown]
# ## Q3

# %%
def gener3(a, b, m, seed):
    x = seed
    u = x/m
    ui = []
    ui.append(u)
    checker = dict()
    checker[x]=1
    for _ in range(10000):
        x = (a*x + b) % m
        u = x/m
        if (x==0): continue
        if x in checker:
            break
        else:
            checker[x]=1
        ui.append(u)
        
    return ui

# %%
u1 = gener3(1229, 1, 2048, 1)
u2 = gener3(1229, 1, 2048, 1)

del u1[len(u1)-1]
del u2[0]

# %% [markdown]
# ## Q3

# %%
fig, sx = plt.subplots()
sx.scatter(u1, u2, alpha=0.1, color='g', linewidths=0.01)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Question 3 plot")
plt.show()

# %% [markdown]
# ---
